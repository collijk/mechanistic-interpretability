# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Looking in indexes: https://pypi.org/simple, https://artifactory.ihme.washington.edu/artifactory/api/pypi/pypi-shared/simple
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-cnefp3le
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-cnefp3le
#   Resolved https://github.com/greydanus/mnist1d to commit 350929d12f4c9a4b7355e0c96604e41b9239bdb4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from mnist1d==0.0.2.post9) (2.32.3)
# Requirement already satisfied: numpy in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from mnist1d==0.0.2.post9) (2.0.0)
# Requirement already satisfied: matplotlib in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from mnist1d==0.0.2.post9) (3.9.1)
# Requirement already satisfied: scipy in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from mnist1d==0.0.2.post9) (1.14.0)
# Requirement already satisfied: contourpy>=1.0.1 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (24.1)
# Requirement already satisfied: pillow>=8 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from matplotlib->mnist1d==0.0.2.post9) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post9) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post9) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from requests->mnist1d==0.0.2.post9) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /mnt/share/code/collijk/miniconda/envs/mi/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post9) (1.16.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %% [markdown]
# 1. The training error should hit zero a bit before we hit 4000 parameters. Because we have 2 layers in the model, the model capacity increases faster than the number of parameters.
# 2. The first minima will be wherever we minimize the bias/variance tradeoff.  It is hopefully well before we hit N(params) = N(train)
# 3. The max should be right where we hit N(params) = N(train)

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.304111, train error 90.05,  test loss 2.304962, test error 90.47
# Epoch   100, train loss 2.211715, train error 87.75,  test loss 2.210352, test error 88.78
# Epoch   200, train loss 1.912046, train error 71.93,  test loss 1.753677, test error 69.85
# Epoch   300, train loss 1.905754, train error 71.65,  test loss 1.742721, test error 70.43
# Epoch   400, train loss 1.902518, train error 70.68,  test loss 1.742356, test error 69.97
# Epoch   500, train loss 1.902920, train error 70.93,  test loss 1.739455, test error 69.62
# Epoch   600, train loss 1.902099, train error 71.12,  test loss 1.741009, test error 69.53
# Epoch   700, train loss 1.904372, train error 70.85,  test loss 1.732940, test error 69.88
# Epoch   800, train loss 1.901313, train error 70.80,  test loss 1.739286, test error 69.47
# Epoch   900, train loss 1.901624, train error 70.40,  test loss 1.741773, test error 69.68
# Training model with   4 hidden variables
# Epoch     0, train loss 2.243406, train error 83.28,  test loss 2.233412, test error 82.75
# Epoch   100, train loss 1.782279, train error 66.75,  test loss 1.588969, test error 62.55
# Epoch   200, train loss 1.742399, train error 62.72,  test loss 1.529486, test error 59.58
# Epoch   300, train loss 1.724798, train error 63.35,  test loss 1.517180, test error 60.08
# Epoch   400, train loss 1.707345, train error 61.88,  test loss 1.503653, test error 58.35
# Epoch   500, train loss 1.699352, train error 60.62,  test loss 1.490891, test error 57.72
# Epoch   600, train loss 1.692027, train error 60.72,  test loss 1.491933, test error 56.92
# Epoch   700, train loss 1.692831, train error 60.53,  test loss 1.493741, test error 57.50
# Epoch   800, train loss 1.692262, train error 60.97,  test loss 1.494861, test error 56.55
# Epoch   900, train loss 1.690731, train error 60.30,  test loss 1.494151, test error 56.72
# Training model with   6 hidden variables
# Epoch     0, train loss 2.299625, train error 88.93,  test loss 2.296074, test error 88.40
# Epoch   100, train loss 1.638087, train error 57.08,  test loss 1.469818, test error 56.00
# Epoch   200, train loss 1.590838, train error 55.70,  test loss 1.434098, test error 54.72
# Epoch   300, train loss 1.573383, train error 55.00,  test loss 1.425021, test error 54.08
# Epoch   400, train loss 1.572898, train error 54.85,  test loss 1.423685, test error 53.72
# Epoch   500, train loss 1.569064, train error 54.85,  test loss 1.424680, test error 53.80
# Epoch   600, train loss 1.564705, train error 54.45,  test loss 1.418015, test error 54.20
# Epoch   700, train loss 1.564396, train error 54.17,  test loss 1.423250, test error 54.10
# Epoch   800, train loss 1.562969, train error 54.08,  test loss 1.426714, test error 54.12
# Epoch   900, train loss 1.564928, train error 54.00,  test loss 1.427075, test error 54.00
# Training model with   8 hidden variables
# Epoch     0, train loss 2.213585, train error 82.32,  test loss 2.194617, test error 82.00
# Epoch   100, train loss 1.608102, train error 57.72,  test loss 1.444698, test error 56.60
# Epoch   200, train loss 1.579709, train error 56.33,  test loss 1.433868, test error 56.47
# Epoch   300, train loss 1.562056, train error 56.25,  test loss 1.422904, test error 55.20
# Epoch   400, train loss 1.548192, train error 55.45,  test loss 1.428552, test error 55.55
# Epoch   500, train loss 1.552498, train error 55.75,  test loss 1.448599, test error 56.50
# Epoch   600, train loss 1.543388, train error 55.38,  test loss 1.441184, test error 55.83
# Epoch   700, train loss 1.539219, train error 55.08,  test loss 1.448447, test error 56.92
# Epoch   800, train loss 1.543125, train error 55.62,  test loss 1.452557, test error 56.42
# Epoch   900, train loss 1.529984, train error 54.58,  test loss 1.447823, test error 56.20
# Training model with  10 hidden variables
# Epoch     0, train loss 2.287852, train error 86.47,  test loss 2.293168, test error 86.95
# Epoch   100, train loss 1.551817, train error 53.72,  test loss 1.410033, test error 53.62
# Epoch   200, train loss 1.460783, train error 49.53,  test loss 1.310142, test error 48.35
# Epoch   300, train loss 1.433043, train error 48.58,  test loss 1.308465, test error 48.65
# Epoch   400, train loss 1.425279, train error 48.35,  test loss 1.313454, test error 48.90
# Epoch   500, train loss 1.413298, train error 48.55,  test loss 1.307753, test error 48.20
# Epoch   600, train loss 1.409488, train error 48.20,  test loss 1.309410, test error 48.05
# Epoch   700, train loss 1.415080, train error 48.30,  test loss 1.310880, test error 48.22
# Epoch   800, train loss 1.403568, train error 47.60,  test loss 1.303399, test error 48.15
# Epoch   900, train loss 1.398901, train error 48.12,  test loss 1.305423, test error 47.83
# Training model with  14 hidden variables
# Epoch     0, train loss 2.288693, train error 86.53,  test loss 2.284568, test error 86.45
# Epoch   100, train loss 1.484067, train error 50.28,  test loss 1.385006, test error 52.75
# Epoch   200, train loss 1.381899, train error 46.42,  test loss 1.371474, test error 50.95
# Epoch   300, train loss 1.342448, train error 45.45,  test loss 1.409273, test error 51.33
# Epoch   400, train loss 1.322638, train error 43.78,  test loss 1.413823, test error 51.47
# Epoch   500, train loss 1.305373, train error 43.78,  test loss 1.416822, test error 51.42
# Epoch   600, train loss 1.290780, train error 43.30,  test loss 1.428503, test error 51.05
# Epoch   700, train loss 1.292920, train error 43.28,  test loss 1.446630, test error 51.62
# Epoch   800, train loss 1.285982, train error 43.65,  test loss 1.460674, test error 52.00
# Epoch   900, train loss 1.279604, train error 42.95,  test loss 1.449176, test error 51.65
# Training model with  18 hidden variables
# Epoch     0, train loss 2.160171, train error 80.32,  test loss 2.116506, test error 77.97
# Epoch   100, train loss 1.443413, train error 50.35,  test loss 1.419132, test error 53.83
# Epoch   200, train loss 1.281041, train error 42.95,  test loss 1.342265, test error 48.90
# Epoch   300, train loss 1.233190, train error 40.80,  test loss 1.378392, test error 49.72
# Epoch   400, train loss 1.197943, train error 40.38,  test loss 1.402189, test error 48.97
# Epoch   500, train loss 1.181598, train error 40.42,  test loss 1.424241, test error 49.38
# Epoch   600, train loss 1.165623, train error 40.30,  test loss 1.450643, test error 49.83
# Epoch   700, train loss 1.153289, train error 39.40,  test loss 1.451486, test error 49.62
# Epoch   800, train loss 1.143853, train error 39.22,  test loss 1.470514, test error 50.03
# Epoch   900, train loss 1.139203, train error 39.05,  test loss 1.499852, test error 50.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.110271, train error 79.68,  test loss 2.058889, test error 78.18
# Epoch   100, train loss 1.289289, train error 43.85,  test loss 1.318947, test error 49.17
# Epoch   200, train loss 1.163085, train error 40.45,  test loss 1.355640, test error 50.03
# Epoch   300, train loss 1.105833, train error 38.40,  test loss 1.437204, test error 50.92
# Epoch   400, train loss 1.060770, train error 36.95,  test loss 1.522026, test error 52.00
# Epoch   500, train loss 1.044689, train error 36.33,  test loss 1.610060, test error 53.47
# Epoch   600, train loss 1.010644, train error 35.20,  test loss 1.644672, test error 51.70
# Epoch   700, train loss 0.996150, train error 34.65,  test loss 1.740818, test error 52.72
# Epoch   800, train loss 0.976763, train error 34.65,  test loss 1.779413, test error 53.05
# Epoch   900, train loss 0.965312, train error 33.68,  test loss 1.837393, test error 53.12
# Training model with  26 hidden variables
# Epoch     0, train loss 2.210137, train error 81.88,  test loss 2.200635, test error 82.03
# Epoch   100, train loss 1.178930, train error 39.28,  test loss 1.357602, test error 49.42
# Epoch   200, train loss 1.019859, train error 34.68,  test loss 1.500627, test error 51.12
# Epoch   300, train loss 0.955404, train error 32.35,  test loss 1.612670, test error 51.70
# Epoch   400, train loss 0.920679, train error 31.90,  test loss 1.766279, test error 53.33
# Epoch   500, train loss 0.888479, train error 31.15,  test loss 1.847092, test error 53.67
# Epoch   600, train loss 0.862703, train error 29.75,  test loss 1.920711, test error 54.03
# Epoch   700, train loss 0.857799, train error 29.75,  test loss 2.010559, test error 53.92
# Epoch   800, train loss 0.841381, train error 28.82,  test loss 2.081255, test error 54.55
# Epoch   900, train loss 0.823397, train error 28.22,  test loss 2.155216, test error 54.33
# Training model with  30 hidden variables
# Epoch     0, train loss 2.151591, train error 80.30,  test loss 2.120892, test error 79.80
# Epoch   100, train loss 1.111129, train error 36.92,  test loss 1.337521, test error 49.80
# Epoch   200, train loss 0.934235, train error 30.50,  test loss 1.481310, test error 50.47
# Epoch   300, train loss 0.831086, train error 28.15,  test loss 1.676737, test error 50.90
# Epoch   400, train loss 0.804895, train error 27.75,  test loss 1.863922, test error 52.92
# Epoch   500, train loss 0.750188, train error 25.38,  test loss 1.992402, test error 53.20
# Epoch   600, train loss 0.719583, train error 24.15,  test loss 2.103474, test error 53.83
# Epoch   700, train loss 0.697369, train error 23.55,  test loss 2.152228, test error 52.85
# Epoch   800, train loss 0.710121, train error 24.47,  test loss 2.257198, test error 54.00
# Epoch   900, train loss 0.679750, train error 24.05,  test loss 2.345948, test error 55.00
# Training model with  35 hidden variables
# Epoch     0, train loss 2.103711, train error 77.78,  test loss 2.064527, test error 77.03
# Epoch   100, train loss 0.959511, train error 30.60,  test loss 1.416764, test error 49.60
# Epoch   200, train loss 0.771569, train error 24.47,  test loss 1.712176, test error 50.95
# Epoch   300, train loss 0.651656, train error 21.22,  test loss 2.042942, test error 52.25
# Epoch   400, train loss 0.580757, train error 19.05,  test loss 2.445465, test error 53.35
# Epoch   500, train loss 0.521180, train error 17.75,  test loss 2.797512, test error 54.42
# Epoch   600, train loss 0.490635, train error 16.43,  test loss 3.161352, test error 55.58
# Epoch   700, train loss 0.473195, train error 15.65,  test loss 3.574584, test error 56.80
# Epoch   800, train loss 0.418771, train error 13.72,  test loss 3.837193, test error 56.55
# Epoch   900, train loss 0.437570, train error 15.15,  test loss 4.143023, test error 56.28
# Training model with  40 hidden variables
# Epoch     0, train loss 2.050937, train error 77.45,  test loss 1.984381, test error 77.12
# Epoch   100, train loss 0.925805, train error 30.12,  test loss 1.427746, test error 50.50
# Epoch   200, train loss 0.620288, train error 19.57,  test loss 1.922692, test error 53.08
# Epoch   300, train loss 0.500345, train error 16.25,  test loss 2.525954, test error 54.20
# Epoch   400, train loss 0.383171, train error 12.05,  test loss 3.224572, test error 54.97
# Epoch   500, train loss 0.417819, train error 14.97,  test loss 4.013341, test error 56.45
# Epoch   600, train loss 0.376484, train error 13.50,  test loss 4.665563, test error 57.17
# Epoch   700, train loss 0.283322, train error 9.65,  test loss 5.390922, test error 57.15
# Epoch   800, train loss 0.241083, train error 8.60,  test loss 6.004889, test error 57.47
# Epoch   900, train loss 0.247093, train error 8.80,  test loss 6.632061, test error 58.10
# Training model with  45 hidden variables
# Epoch     0, train loss 2.055138, train error 75.50,  test loss 2.000574, test error 75.32
# Epoch   100, train loss 0.799661, train error 24.90,  test loss 1.433664, test error 49.15
# Epoch   200, train loss 0.471930, train error 14.22,  test loss 2.218872, test error 53.58
# Epoch   300, train loss 0.333217, train error 10.57,  test loss 3.274666, test error 53.88
# Epoch   400, train loss 0.203589, train error 6.00,  test loss 4.660666, test error 57.05
# Epoch   500, train loss 0.166714, train error 5.40,  test loss 6.018135, test error 56.78
# Epoch   600, train loss 0.174134, train error 6.07,  test loss 7.246508, test error 57.20
# Epoch   700, train loss 0.011992, train error 0.00,  test loss 8.218875, test error 56.60
# Epoch   800, train loss 0.007692, train error 0.00,  test loss 8.881453, test error 56.85
# Epoch   900, train loss 0.005751, train error 0.00,  test loss 9.387128, test error 56.85
# Training model with  50 hidden variables
# Epoch     0, train loss 2.062367, train error 76.43,  test loss 2.016609, test error 77.10
# Epoch   100, train loss 0.689063, train error 21.38,  test loss 1.478341, test error 49.05
# Epoch   200, train loss 0.310298, train error 8.75,  test loss 2.543785, test error 52.53
# Epoch   300, train loss 0.121194, train error 2.57,  test loss 4.092003, test error 54.58
# Epoch   400, train loss 0.024003, train error 0.00,  test loss 5.413555, test error 54.70
# Epoch   500, train loss 0.012287, train error 0.00,  test loss 6.212649, test error 55.00
# Epoch   600, train loss 0.007564, train error 0.00,  test loss 6.753171, test error 55.15
# Epoch   700, train loss 0.005474, train error 0.00,  test loss 7.156291, test error 55.17
# Epoch   800, train loss 0.004269, train error 0.00,  test loss 7.484781, test error 55.08
# Epoch   900, train loss 0.003433, train error 0.00,  test loss 7.764877, test error 55.00
# Training model with  55 hidden variables
# Epoch     0, train loss 2.053272, train error 76.25,  test loss 1.995610, test error 75.90
# Epoch   100, train loss 0.628641, train error 19.05,  test loss 1.628091, test error 50.65
# Epoch   200, train loss 0.204904, train error 4.93,  test loss 2.967686, test error 53.88
# Epoch   300, train loss 0.039048, train error 0.07,  test loss 4.636788, test error 54.33
# Epoch   400, train loss 0.014783, train error 0.00,  test loss 5.671200, test error 54.28
# Epoch   500, train loss 0.008585, train error 0.00,  test loss 6.292344, test error 54.50
# Epoch   600, train loss 0.005834, train error 0.00,  test loss 6.729951, test error 54.38
# Epoch   700, train loss 0.004356, train error 0.00,  test loss 7.073058, test error 54.50
# Epoch   800, train loss 0.003442, train error 0.00,  test loss 7.354534, test error 54.53
# Epoch   900, train loss 0.002819, train error 0.00,  test loss 7.591280, test error 54.72
# Training model with  60 hidden variables
# Epoch     0, train loss 2.046283, train error 76.00,  test loss 2.000483, test error 76.93
# Epoch   100, train loss 0.517391, train error 14.25,  test loss 1.697340, test error 49.22
# Epoch   200, train loss 0.092450, train error 0.78,  test loss 3.301094, test error 53.38
# Epoch   300, train loss 0.019032, train error 0.00,  test loss 4.575261, test error 53.72
# Epoch   400, train loss 0.009345, train error 0.00,  test loss 5.201173, test error 53.65
# Epoch   500, train loss 0.005990, train error 0.00,  test loss 5.632124, test error 53.65
# Epoch   600, train loss 0.004291, train error 0.00,  test loss 5.946931, test error 53.78
# Epoch   700, train loss 0.003281, train error 0.00,  test loss 6.201741, test error 53.70
# Epoch   800, train loss 0.002647, train error 0.00,  test loss 6.408738, test error 53.78
# Epoch   900, train loss 0.002203, train error 0.00,  test loss 6.589623, test error 53.62
# Training model with  70 hidden variables
# Epoch     0, train loss 2.061023, train error 76.57,  test loss 2.013742, test error 75.72
# Epoch   100, train loss 0.380739, train error 9.68,  test loss 1.904121, test error 51.40
# Epoch   200, train loss 0.036794, train error 0.03,  test loss 3.581262, test error 53.47
# Epoch   300, train loss 0.011581, train error 0.00,  test loss 4.406863, test error 53.60
# Epoch   400, train loss 0.006463, train error 0.00,  test loss 4.865381, test error 53.55
# Epoch   500, train loss 0.004344, train error 0.00,  test loss 5.184585, test error 53.78
# Epoch   600, train loss 0.003202, train error 0.00,  test loss 5.422931, test error 53.58
# Epoch   700, train loss 0.002504, train error 0.00,  test loss 5.619351, test error 53.62
# Epoch   800, train loss 0.002044, train error 0.00,  test loss 5.782579, test error 53.55
# Epoch   900, train loss 0.001716, train error 0.00,  test loss 5.922222, test error 53.53
# Training model with  80 hidden variables
# Epoch     0, train loss 2.025383, train error 73.97,  test loss 1.988912, test error 74.85
# Epoch   100, train loss 0.229997, train error 3.97,  test loss 2.291511, test error 54.28
# Epoch   200, train loss 0.020450, train error 0.00,  test loss 3.809713, test error 54.80
# Epoch   300, train loss 0.008049, train error 0.00,  test loss 4.432240, test error 54.92
# Epoch   400, train loss 0.004767, train error 0.00,  test loss 4.810606, test error 54.92
# Epoch   500, train loss 0.003306, train error 0.00,  test loss 5.077545, test error 54.83
# Epoch   600, train loss 0.002479, train error 0.00,  test loss 5.283829, test error 54.85
# Epoch   700, train loss 0.001968, train error 0.00,  test loss 5.449540, test error 54.88
# Epoch   800, train loss 0.001621, train error 0.00,  test loss 5.591232, test error 54.97
# Epoch   900, train loss 0.001372, train error 0.00,  test loss 5.712959, test error 54.83
# Training model with  90 hidden variables
# Epoch     0, train loss 2.023416, train error 75.75,  test loss 1.982986, test error 75.15
# Epoch   100, train loss 0.147859, train error 1.25,  test loss 2.210075, test error 52.08
# Epoch   200, train loss 0.015164, train error 0.00,  test loss 3.292022, test error 52.70
# Epoch   300, train loss 0.006713, train error 0.00,  test loss 3.734860, test error 52.53
# Epoch   400, train loss 0.004089, train error 0.00,  test loss 4.003733, test error 52.53
# Epoch   500, train loss 0.002864, train error 0.00,  test loss 4.200727, test error 52.45
# Epoch   600, train loss 0.002178, train error 0.00,  test loss 4.351969, test error 52.45
# Epoch   700, train loss 0.001738, train error 0.00,  test loss 4.477845, test error 52.38
# Epoch   800, train loss 0.001438, train error 0.00,  test loss 4.583712, test error 52.47
# Epoch   900, train loss 0.001220, train error 0.00,  test loss 4.675095, test error 52.50
# Training model with 100 hidden variables
# Epoch     0, train loss 2.013137, train error 74.60,  test loss 1.982214, test error 76.60
# Epoch   100, train loss 0.107388, train error 0.32,  test loss 2.262779, test error 51.40
# Epoch   200, train loss 0.012615, train error 0.00,  test loss 3.169978, test error 51.62
# Epoch   300, train loss 0.005794, train error 0.00,  test loss 3.567775, test error 51.80
# Epoch   400, train loss 0.003591, train error 0.00,  test loss 3.810063, test error 51.70
# Epoch   500, train loss 0.002547, train error 0.00,  test loss 3.984966, test error 51.55
# Epoch   600, train loss 0.001952, train error 0.00,  test loss 4.121684, test error 51.65
# Epoch   700, train loss 0.001565, train error 0.00,  test loss 4.235417, test error 51.58
# Epoch   800, train loss 0.001299, train error 0.00,  test loss 4.331438, test error 51.60
# Epoch   900, train loss 0.001106, train error 0.00,  test loss 4.414424, test error 51.65
# Training model with 120 hidden variables
# Epoch     0, train loss 1.966725, train error 72.47,  test loss 1.915368, test error 74.35
# Epoch   100, train loss 0.051653, train error 0.00,  test loss 2.185301, test error 49.85
# Epoch   200, train loss 0.009602, train error 0.00,  test loss 2.809915, test error 49.67
# Epoch   300, train loss 0.004742, train error 0.00,  test loss 3.096933, test error 49.90
# Epoch   400, train loss 0.003030, train error 0.00,  test loss 3.279844, test error 50.00
# Epoch   500, train loss 0.002186, train error 0.00,  test loss 3.417514, test error 50.08
# Epoch   600, train loss 0.001688, train error 0.00,  test loss 3.526159, test error 50.20
# Epoch   700, train loss 0.001364, train error 0.00,  test loss 3.615873, test error 50.22
# Epoch   800, train loss 0.001139, train error 0.00,  test loss 3.691387, test error 50.15
# Epoch   900, train loss 0.000973, train error 0.00,  test loss 3.757770, test error 50.15
# Training model with 140 hidden variables
# Epoch     0, train loss 1.994758, train error 74.00,  test loss 1.917840, test error 73.85
# Epoch   100, train loss 0.034869, train error 0.00,  test loss 2.174031, test error 48.75
# Epoch   200, train loss 0.007904, train error 0.00,  test loss 2.655648, test error 48.88
# Epoch   300, train loss 0.004069, train error 0.00,  test loss 2.883795, test error 48.95
# Epoch   400, train loss 0.002647, train error 0.00,  test loss 3.034322, test error 48.92
# Epoch   500, train loss 0.001929, train error 0.00,  test loss 3.146562, test error 48.92
# Epoch   600, train loss 0.001501, train error 0.00,  test loss 3.235933, test error 48.97
# Epoch   700, train loss 0.001219, train error 0.00,  test loss 3.311130, test error 48.90
# Epoch   800, train loss 0.001021, train error 0.00,  test loss 3.374408, test error 49.00
# Epoch   900, train loss 0.000875, train error 0.00,  test loss 3.429690, test error 49.05
# Training model with 160 hidden variables
# Epoch     0, train loss 1.943023, train error 70.80,  test loss 1.883863, test error 71.78
# Epoch   100, train loss 0.028854, train error 0.00,  test loss 2.041690, test error 47.72

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
