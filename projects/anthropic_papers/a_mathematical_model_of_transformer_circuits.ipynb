# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F

# %%
class ZeroLayerTransformer(nn.Module):
    def __init__(self, vocab_size: int, d_model: int):
        # TODO: Initialize embedding and unembedding layers
        # Hint: You'll need:
        # - embedding layer: vocab_size → d_model
        # - unembedding layer: d_model → vocab_size        
        super().__init__()
        self.vocab_size = vocab_size
        self.d_model = d_model
        self.embed = nn.Linear(vocab_size, d_model)
        self.unembed = nn.Linear(d_model, vocab_size, bias=False)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        # Input is token indices in shape [batch_size, seq_len]
        # Output shape: [batch_size, seq_len, vocab_size]
        x_one_hot = F.one_hot(x)
        embeddings = self.embed(x_one_hot)
        logits = self.unembed(embeddings)
        return logits

    def get_bigram_matrix(self) -> torch.Tensor:
        # TODO: Return matrix of token transition probabilities
        # Hint: Multiply embedding and unembedding matrices
        pass

# %%
vocab_size = 1000
d_model = 96
t = ZeroLayerTransformer(vocab_size, d_model)

# %%
print(t.embed.weight.shape)
print(t.unembed.weight.shape)
# Out:
# torch.Size([96, 1000])
# torch.Size([1000, 96])

# %%
class TextDataset(Dataset):
    def __init__(self, text: str, seq_len: int):
        # TODO: Initialize dataset
        # - Create vocabulary (char to index mapping)
        # - Convert text to tensor of indices
        # - Store sequence length
        self.chars = sorted(list(set(text)))
        self.vocab_size = len(self.chars)
        self.stoi = {s: i for i, s in enumerate(self.chars)}
        self.itos = {i: s for i, s in enumerate(self.chars)}
        

    def __len__(self) -> int:
        # TODO: Return number of possible sequences
        pass

    def __getitem__(self, idx: int) -> Tuple[torch.Tensor, torch.Tensor]:
        # TODO: Return sequence and target
        # - Sequence: tensor of indices
        # - Target: next token for each position
        pass

def train_epoch(
    model: nn.Module,
    dataloader: DataLoader,
    optimizer: torch.optim.Optimizer
) -> float:
    # TODO: Implement single training epoch
    # - Iterate through batches
    # - Compute loss
    # - Update model
    # Return average loss
    pass

def main():
    # TODO: Implement training loop
    # 1. Create dataset and dataloader
    # 2. Initialize model
    # 3. Train model
    # 4. Analyze learned bigram statistics
    pass

if __name__ == "__main__":
    main()
